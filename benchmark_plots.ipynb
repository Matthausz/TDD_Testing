# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors

# %% [markdown]
# # Runtime Scalling For Qubits, Gate count, and Controlled gate count

# %%
# Read the benchmark results file into a DataFrame
df = pd.read_csv("statevector_benchmark.txt")

# Plot the scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(df['Number of Qubits'], df['Time (s)'], c='blue', alpha=0.5)
plt.title('Run Time vs Number of Qubits for Qiskit Aer Statevector Backend')
plt.xlabel('Number of Qubits')
plt.ylabel('Time (s)')
plt.grid(True)
plt.show()

# Plot the scatter plot
plt.figure(figsize=(10, 6))
scatter=plt.scatter(df['Number of Gates'], df['Time (s)'], c=df['Number of Qubits'], cmap='viridis',norm=mcolors.LogNorm(), alpha=0.7)
plt.colorbar(scatter, label='Number of Qubits')
plt.title('Run Time vs Number of Gates for Qiskit Aer Statevector Backend')
plt.xlabel('Number of Gates')
plt.ylabel('Time (s)')
plt.yscale("log")
plt.xscale("log")
plt.grid(True)
plt.show()

# Plot the scatter plot
plt.figure(figsize=(10, 6))
scatter=plt.scatter(df['Number of Controlled Gates'], df['Time (s)'], c=df['Number of Qubits'], cmap='viridis',norm=mcolors.LogNorm(), alpha=0.7)
plt.colorbar(scatter, label='Number of Qubits')
plt.title('Run Time vs Number of Controlled Gates for Qiskit Aer Statevector Backend')
plt.xlabel('Number of Controlled  Gates')
plt.ylabel('Time (s)')
plt.yscale("log")
plt.xscale("log")
plt.grid(True)
plt.show()

# %%
#QFT only runs
df = pd.read_csv("statevector_benchmark.txt")
# Filter out examples that don't have a circuit name starting with "QFT"
df = df[df['Circuit Name'].str.startswith('qft')]

# Convert "TO" values to NaN for easier handling
df['Time (s)'] = pd.to_numeric(df['Time (s)'], errors='coerce')

# Generate scatter plot
plt.figure(figsize=(10, 6))
scatter = plt.scatter(df['Number of Gates'], df['Time (s)'], c=df['Number of Qubits'], cmap='viridis',norm=mcolors.LogNorm(),alpha=0.7)
plt.colorbar(scatter, label='Number of Qubits')
plt.xlabel('Number of Gates')
plt.ylabel('Time (s)')
plt.title('Time vs Number of Gates For QFT with Statevector')
plt.grid(True)
plt.show()

# %%
# Read the benchmark results file into a DataFrame
df = pd.read_csv("matrix_product_state_benchmark.txt")

# Plot the scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(df['Number of Qubits'], df['Time (s)'], c='blue', alpha=0.5)
plt.title('Run Time vs Number of Qubits for Qiskit Aer MPS Backend')
plt.xlabel('Number of Qubits')
plt.ylabel('Time (s)')
plt.grid(True)
plt.show()

# Plot the scatter plot
plt.figure(figsize=(10, 6))
scatter=plt.scatter(df['Number of Gates'], df['Time (s)'], c=df['Number of Qubits'], cmap='viridis', norm=mcolors.LogNorm(),alpha=0.7)
plt.colorbar(scatter, label='Number of Qubits')
plt.title('Run Time vs Number of Gates for Qiskit Aer MPS Backend')
plt.xlabel('Number of Gates')
plt.ylabel('Time (s)')
plt.yscale("log")
plt.xscale("log")
plt.grid(True)
plt.show()

# Plot the scatter plot
plt.figure(figsize=(10, 6))
scatter=plt.scatter(df['Number of Controlled Gates'], df['Time (s)'],c=df['Number of Qubits'], cmap='viridis',norm=mcolors.LogNorm(), alpha=0.7)
plt.colorbar(scatter, label='Number of Qubits')
plt.title('Run Time vs Number of Controlled Gates for Qiskit Aer MPS Backend')
plt.xlabel('Number of Controlled Gates')
plt.ylabel('Time (s)')
plt.yscale("log")
plt.xscale("log")
plt.grid(True)
plt.show()

# %%
#QFT only runs
df = pd.read_csv("matrix_product_state_benchmark.txt")
# Filter out examples that don't have a circuit name starting with "QFT"
df = df[df['Circuit Name'].str.startswith('qft')]

# Convert "TO" values to NaN for easier handling
df['Time (s)'] = pd.to_numeric(df['Time (s)'], errors='coerce')

# Generate scatter plot
plt.figure(figsize=(10, 6))
scatter = plt.scatter(df['Number of Gates'], df['Time (s)'], c=df['Number of Qubits'], cmap='viridis', norm=mcolors.LogNorm(),alpha=0.7)
plt.colorbar(scatter, label='Number of Qubits')
plt.xlabel('Number of Gates')
plt.ylabel('Time (s)')
plt.title('Time vs Number of Gates For QFT with MPS')
plt.grid(True)
plt.show()

# %%
# Read the benchmark results file into a DataFrame
df = pd.read_csv("TDD_benchmark.txt")

# Plot the scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(df['Number of Qubits'], df['Time (s)'], c="blue", alpha=0.7)
plt.title('Run Time vs Number of Qubits for TDD')
plt.xlabel('Number of Qubits')
plt.ylabel('Time (s)')
plt.grid(True)
plt.show()

# Plot the scatter plot
plt.figure(figsize=(10, 6))
scatter=plt.scatter(df['Number of Gates'], df['Time (s)'], c=df['Number of Qubits'], cmap='viridis', norm=mcolors.LogNorm(),alpha=0.7)
plt.colorbar(scatter, label='Number of Qubits')
plt.title('Run Time vs Number of Gates for TDD')
plt.xlabel('Number of Gates')
plt.ylabel('Time (s)')
plt.yscale("log")
plt.xscale("log")
plt.grid(True)
plt.show()

# Plot the scatter plot
plt.figure(figsize=(10, 6))
scatter=plt.scatter(df['Number of Controlled Gates'], df['Time (s)'], c=df['Number of Qubits'],cmap='viridis' , norm=mcolors.LogNorm(), alpha=0.7)
plt.colorbar(scatter, label='Number of Qubits')
plt.title('Run Time vs Number of Controlled Gates for TDD')
plt.xlabel('Number of Controlled Gates')
plt.ylabel('Time (s)')
plt.yscale("log")
plt.xscale("log")
plt.grid(True)
plt.show()

# %%
fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(np.log(df['Number of Gates']), np.log(df['Number of Controlled Gates']), df['Time (s)'], c='blue', alpha=0.5)
ax.view_init(elev=15, azim=25) 
ax.set_xlabel('Number of Gates')
ax.set_ylabel('Number of Controlled Gates')
ax.set_zlabel('Runtime (s)')
plt.show()
# Out:
# /opt/miniconda3/envs/cits5508-2024/lib/python3.11/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
#QFT only runs
df = pd.read_csv("TDD_benchmark.txt")
# Filter out examples that don't have a circuit name starting with "QFT"
df = df[df['Circuit Name'].str.startswith('qft')]

# Convert "TO" values to NaN for easier handling
df['Time (s)'] = pd.to_numeric(df['Time (s)'], errors='coerce')

# Generate scatter plot
plt.figure(figsize=(10, 6))
scatter = plt.scatter(df['Number of Gates'], df['Time (s)'], c=df['Number of Qubits'], cmap='viridis', norm=mcolors.LogNorm(),alpha=0.7)
plt.colorbar(scatter, label='Number of Qubits')
plt.xlabel('Number of Gates')
plt.ylabel('Time (s)')
plt.title('Time vs Number of Gates For QFT with TDD')
plt.grid(True)
plt.show()

# %% [markdown]
# # Below I try to find what circuits cause the upper branch in the runtime plots
#
# This showed that for some reason quantum_volume and qft circuit architectures scalled worse than the other algorithims.

# %%
#only slow runs
df = pd.read_csv("TDD_benchmark.txt")
# Filter out examples that don't have a circuit name starting with "QFT"
df = df[df['Time (s)']>6]

# Convert "TO" values to NaN for easier handling
df['Time (s)'] = pd.to_numeric(df['Time (s)'], errors='coerce')

# Generate scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(df['Number of Gates'], df['Time (s)'], c="red", alpha=0.7)
plt.xlabel('Number of Gates')
plt.ylabel('Time (s)')
plt.title('Time vs Number of Gates For QFT with TDD')
# Label each dot with the circuit name
for i, txt in enumerate(df['Circuit Name']):
    plt.text(df['Number of Controlled Gates'].iloc[i], df['Time (s)'].iloc[i], txt, ha='center', va='center', fontsize=8)
plt.grid(True)
plt.show()

# %%
df = pd.read_csv("TDD_benchmark.txt")
# Convert "TO" values to NaN for easier handling
df['Time (s)'] = pd.to_numeric(df['Time (s)'], errors='coerce')

# Filter out examples that arent correct circuit type
df1 = df[df['Circuit Name'].str.startswith('quantum_volume')]
df2 = df[df['Circuit Name'].str.startswith('qft')]
df3=df[~df['Circuit Name'].str.startswith(('qft', 'quantum'))]

# Generate scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(df1['Number of Gates'], df1['Time (s)'], c="red", alpha=0.7)
plt.scatter(df2['Number of Gates'], df2['Time (s)'], c="yellow", alpha=0.7)
scatter=plt.scatter(df3['Number of Gates'], df3['Time (s)'], c=df3['Number of Qubits'], cmap='viridis', alpha=0.27)
plt.colorbar(scatter, label='Number of Qubits')
plt.xlabel('Number of Gates')
plt.ylabel('Time (s)')
plt.legend(["Quantum_Volume","QFT","Other"])
plt.title('Time vs Number of Gates For QFT with TDD')
plt.yscale("log")
plt.xscale("log")
plt.grid(True)
plt.show()

# %%
df = pd.read_csv("TDD_benchmark.txt")
# Convert "TO" values to NaN for easier handling
df['Time (s)'] = pd.to_numeric(df['Time (s)'], errors='coerce')

# Filter out examples that arent correct circuit type
df1 = df[df['Circuit Name'].str.startswith('quantum_volume')]
df2 = df[df['Circuit Name'].str.startswith('qft')]
df3=df[~df['Circuit Name'].str.startswith(('qft', 'quantum'))]

# Generate scatter plot
plt.figure(figsize=(15, 8))
scatter1=plt.scatter(df1['Number of Controlled Gates'], df1['Time (s)'], c=df1['Number of Qubits'], cmap='Greens', alpha=1.0)
plt.colorbar(scatter1, label='Number of Qubits Quantum Volume')
scatter2=plt.scatter(df2['Number of Controlled Gates'], df2['Time (s)'],c=df2['Number of Qubits'], cmap='Reds', alpha=0.7)
plt.colorbar(scatter2, label='Number of Qubits QFT')
scatter=plt.scatter(df3['Number of Controlled Gates'], df3['Time (s)'], c=df3['Number of Qubits'], cmap='winter', alpha=0.70)
plt.colorbar(scatter, label='Number of Qubits')
plt.xlabel('Number of Controlled Gates')
plt.ylabel('Time (s)')
plt.legend(["Quantum_Volume","QFT","Other"])
plt.title('Run Time vs Number of Controlled Gates For QFT with TDD')
plt.yscale("log")
plt.xscale("log")
plt.grid(True)
plt.show()

# %%
df = pd.read_csv("matrix_product_state_benchmark.txt")
# Convert "TO" values to NaN for easier handling
df['Time (s)'] = pd.to_numeric(df['Time (s)'], errors='coerce')

# Filter out examples that arent correct circuit type
df1 = df[df['Circuit Name'].str.startswith('quantum_volume')]
df2 = df[df['Circuit Name'].str.startswith('qft')]
df3=df[~df['Circuit Name'].str.startswith(('qft', 'quantum'))]

# Generate scatter plot
plt.figure(figsize=(15, 8))
scatter1=plt.scatter(df1['Number of Controlled Gates'], df1['Time (s)'], c=df1['Number of Qubits'], cmap='Greens', alpha=1.0)
plt.colorbar(scatter1, label='Number of Qubits Quantum Volume')
scatter2=plt.scatter(df2['Number of Controlled Gates'], df2['Time (s)'],c=df2['Number of Qubits'], cmap='Reds', alpha=0.7)
plt.colorbar(scatter2, label='Number of Qubits QFT')
scatter=plt.scatter(df3['Number of Controlled Gates'], df3['Time (s)'], c=df3['Number of Qubits'], cmap='winter', alpha=0.70)
plt.colorbar(scatter, label='Number of Qubits')
plt.xlabel('Number of Controlled Gates')
plt.ylabel('Time (s)')
plt.legend(["Quantum_Volume","QFT","Other"])
plt.title('Run Time vs Number of Controlled Gates For QFT aer MPS backend')
plt.yscale("log")
plt.xscale("log")
plt.grid(True)
plt.show()

# %% [markdown]
# # Memory Usage:
# Memory was measured across the entire simulation run, with the peak usage being returned. The measurement was done using tracemalloc.

# %%
# Read the benchmark results file into a DataFrame
df = pd.read_csv("statevector_Benchmark_Memory.txt")

# Plot the scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(df['Number of Qubits'], df['Memory Peak (MB)'], c='blue', alpha=0.5)
plt.title('Scatter Plot of Time vs Number of Qubits for Statevector Method')
plt.xlabel('Number of Qubits')
plt.ylabel('Memory Peak (MB)')
plt.grid(True)
plt.show()

# Plot the scatter plot
plt.figure(figsize=(10, 6))
scatter=plt.scatter(df['Number of Gates'], df['Memory Peak (MB)'], c=df['Number of Qubits'], cmap='viridis', norm=mcolors.LogNorm(),alpha=0.7)
plt.colorbar(scatter, label='Number of Qubits')
plt.title('Scatter Plot of Time vs Number of Gates for Statevector Method')
plt.xlabel('Number of Gates')
plt.ylabel('Memory Peak (MB)')
plt.yscale("log")
plt.xscale("log")
plt.grid(True)
plt.show()

# Plot the scatter plot
plt.figure(figsize=(10, 6))
scatter=plt.scatter(df['Number of Controlled Gates'], df['Memory Peak (MB)'], c=df['Number of Qubits'], cmap='viridis',norm=mcolors.LogNorm(), alpha=0.7)
plt.colorbar(scatter, label='Number of Qubits')
plt.title('Scatter Plot of Time vs Number of Controlled Gates for Statevector Method')
plt.xlabel('Number of Controlled Gates')
plt.ylabel('Memory Peak (MB)')
plt.yscale("log")
plt.xscale("log")
plt.grid(True)
plt.show()

# %%
# Read the benchmark results file into a DataFrame
df = pd.read_csv("matrix_product_state_Benchmark_Memory.txt")

# Plot the scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(df['Number of Qubits'], df['Memory Peak (MB)'], c='blue', alpha=0.5)
plt.title('Scatter Plot of Memory Peak vs Number of Qubits for MPS Method')
plt.xlabel('Number of Qubits')
plt.ylabel('Memory Peak (MB)')
plt.grid(True)
plt.show()

# Plot the scatter plot
plt.figure(figsize=(10, 6))
scatter=plt.scatter(df['Number of Gates'], df['Memory Peak (MB)'], c=df['Number of Qubits'], cmap='viridis',norm=mcolors.LogNorm(), alpha=0.7)
plt.colorbar(scatter, label='Number of Qubits')
plt.title('Scatter Plot of Memory Peak vs Number of Gates for MPS Method')
plt.xlabel('Number of Gates')
plt.ylabel('Memory Peak (MB)')
plt.yscale("log")
plt.xscale("log")
plt.grid(True)
plt.show()

# Plot the scatter plot
plt.figure(figsize=(10, 6))
scatter=plt.scatter(df['Number of Controlled Gates'], df['Memory Peak (MB)'],c=df['Number of Qubits'], cmap='viridis',norm=mcolors.LogNorm(), alpha=0.7)
plt.colorbar(scatter, label='Number of Qubits')
plt.title('Scatter Plot of Memory Peak vsNumber of Controlled Gates for MPS Method')
plt.xlabel('Number of Controlled Gates')
plt.ylabel('Memory Peak (MB)')
plt.yscale("log")
plt.xscale("log")
plt.grid(True)
plt.show()

# %%
# Read the benchmark results file into a DataFrame
df = pd.read_csv("TDD_Benchmark_Memory.txt")

# Plot the scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(df['Number of Qubits'], df['Memory Peak (MB)'], c="blue", alpha=0.7)
plt.title('Scatter Plot of Memory Peak vs Number of Qubits for TDD')
plt.xlabel('Number of Qubits')
plt.ylabel('Memory Peak (MB)')
plt.grid(True)
plt.show()

# Plot the scatter plot
plt.figure(figsize=(10, 6))
scatter=plt.scatter(df['Number of Gates'], df['Memory Peak (MB)'], c=df['Number of Qubits'], cmap='viridis', norm=mcolors.LogNorm(),alpha=0.7)
plt.colorbar(scatter, label='Number of Qubits')
plt.title('Scatter Plot of Memory Peak vs Number of Gates for TDD')
plt.xlabel('Number of Gates')
plt.ylabel('Memory Peak (MB)')
plt.yscale("log")
plt.xscale("log")
plt.grid(True)
plt.show()

# Plot the scatter plot
plt.figure(figsize=(10, 6))
scatter=plt.scatter(df['Number of Controlled Gates'], df['Memory Peak (MB)'], c=df['Number of Qubits'], cmap='viridis', norm=mcolors.LogNorm(),alpha=0.7)
plt.colorbar(scatter, label='Number of Qubits')
plt.title('Scatter Plot of Memory Peak vs Number of Controlled Gates for TDD')
plt.xlabel('Number of Controlled Gates')
plt.ylabel('Memory Peak (MB)')
plt.yscale("log")
plt.xscale("log")
plt.grid(True)
plt.show()

# %%
df = pd.read_csv("TDD_Benchmark_Memory.txt")
# Convert "TO" values to NaN for easier handling
df['Memory Peak (MB)'] = pd.to_numeric(df['Memory Peak (MB)'], errors='coerce')

# Filter out examples that arent correct circuit type
df1 = df[df['Circuit Name'].str.startswith('quantum_volume')]
df2 = df[df['Circuit Name'].str.startswith('qft')]

# Generate scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(df1['Number of Gates'], df1['Memory Peak (MB)'], c="red", alpha=0.7)
plt.scatter(df2['Number of Gates'], df2['Memory Peak (MB)'], c="yellow", alpha=0.7)
scatter=plt.scatter(df['Number of Gates'], df['Memory Peak (MB)'], c=df['Number of Qubits'], cmap='viridis', alpha=0.27)
plt.colorbar(scatter, label='Number of Qubits')
plt.xlabel('Number of Gates')
plt.ylabel('Memory Peak (MB)')
plt.legend(["Quantum_Volume","QFT","Other"])
plt.title('Memory Peak vs Number of Gates For QFT with TDD')
plt.yscale("log")
plt.xscale("log")
plt.grid(True)
plt.show()

# %%
df = pd.read_csv("Statevector_Benchmark_Memory.txt")
# Convert "TO" values to NaN for easier handling
df['Memory Peak (MB)'] = pd.to_numeric(df['Memory Peak (MB)'], errors='coerce')

# Filter out examples that arent correct circuit type
df1 = df[df['Circuit Name'].str.startswith('quantum_volume')]
df2 = df[df['Circuit Name'].str.startswith('qft')]

# Generate scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(df1['Number of Gates'], df1['Memory Peak (MB)'], c="red", alpha=0.7)
plt.scatter(df2['Number of Gates'], df2['Memory Peak (MB)'], c="yellow", alpha=0.7)
scatter=plt.scatter(df['Number of Gates'], df['Memory Peak (MB)'], c=df['Number of Qubits'], cmap='viridis', alpha=0.27)
plt.colorbar(scatter, label='Number of Qubits')
plt.xlabel('Number of Gates')
plt.ylabel('Memory Peak (MB)')
plt.legend(["Quantum_Volume","QFT","Other"])
plt.title('Memory Peak vs Number of Gates For QFT with Statevector')
plt.yscale("log")
plt.xscale("log")
plt.grid(True)
plt.show()
